# %%
# !pip install transformers[torch]
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\users\ravz2\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install torch torchvision torchaudio transformers
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\users\ravz2\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install -U sentence-transformers
# Out:
# ...
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=7d17a9edf269dbae6f05e28ed2fe825b1a84443b05b43b9221b04286dd48c4e8
#   Stored in directory: c:\users\ravz2\appdata\local\pip\cache\wheels\71\67\06\162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence-transformers
# ...
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\users\ravz2\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
from PIL import Image
image =  "test2.jpg"
im = Image.open(image)
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1200x1600>

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the API key
api_key = os.getenv("OPENAI_KEY")
ai_api_key = os.getenv("HUGGING_KEY")

# %%
import requests

API_URL_BLIP = "https://api-inference.huggingface.co/models/Salesforce/blip-image-captioning-large"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL_BLIP, headers=headers, data=data)
    return response.json()

while True:
    output = query(image)
    try:
        generated_text = output[0]['generated_text']
        print(generated_text)
        caption1 = generated_text
        break  # Si no hay KeyError, sal del bucle
    except KeyError:
        print("KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...")

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/Salesforce/blip-image-captioning-large"
headers = {"Authorization": "Bearer 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"}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

output = query("guido.PNG")
print(output)
# Out:
# [{'generated_text': 'there is a man standing on the beach with his arms up'}]

# %%
def query_api(filename,url):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(url, headers=headers, data=data)
    return response.json()

# %%
import os
def get_caption(api, api_key, filename):
    generated_text = ""
    while True:
        output = query_api(filename, api)
        try:
            generated_text = output[0]['generated_text']
            caption1 = generated_text
            break  # Si no hay KeyError, sal del bucle
        except KeyError:
            print("KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...")
    return generated_text

# %%
directorio = 'images'
API_URL_VIT = "https://api-inference.huggingface.co/models/nlpconnect/vit-gpt2-image-captioning"
API_URL_GIT = "https://api-inference.huggingface.co/models/microsoft/git-large-coco"

numero_de_archivos = len([nombre for nombre in os.listdir(directorio) if os.path.isfile(os.path.join(directorio, nombre))])
blip_captions = []
vit_captions = []
git_captions = []
# Recorrer cada archivo
for i in range(1, 28):
    # Construir el nombre del archivo
    nombre_archivo = os.path.join(directorio, f"{i}.jpg")

    # Aquí puedes hacer lo que necesites con cada archivo
    print(f"Procesando archivo: {nombre_archivo}")
    blip_captions.append(get_caption(API_URL_BLIP, headers, nombre_archivo))
    vit_captions.append(get_caption(API_URL_VIT, headers, nombre_archivo))
    git_captions.append(get_caption(API_URL_GIT, headers, nombre_archivo))
# Out:
# Procesando archivo: images/1.jpg
# Procesando archivo: images/2.jpg
# Procesando archivo: images/3.jpg
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...
# ...

# %%
blip_captions
# Out:
# ['people crossing a suspension bridge over a river in the mountains',
#  'there are two people sitting on a rock formation with a dog',
#  'there is a man holding a baby in his arms',
#  'there is a man climbing up a snowy mountain with a snowboard',
#  'there are two dogs running in the grass near a house',
#  'there is a woman and a child playing in a pool',
#  'there is a small child that is playing with a toy',
#  'boy sitting on a inflatable slide in a park',
#  'there are two people playing with a water hose in the yard',
#  'several people in a pool with a pool float and a pool toy',
#  'arafed man on a surfboard on a beach with a blue sky',
#  'there is a cat and dog playing together on the couch',
#  'there is a woman standing in a room with a gold wall',
#  'mountains with snow on them and a man with a backpack',
#  'horses pulling a carriage with people in it on a rainy day',
#  'there is a man and a boy pushing a shopping cart in a store',
# ...

# %%
vit_captions
# Out:
# ['a person on a rope climbing a large rock ',
#  'a man riding a rock on top of a rock ',
#  'a man holding a baby in front of a tv ',
#  'a man is skiing down a mountain in the snow ',
#  'two dogs are playing in the grass near a house ',
#  'a woman and child playing in a pool ',
#  'a little boy holding a red and white fire hydrant ',
#  'a young boy is playing with a blue ball ',
#  'a woman is playing frisbee in a field ',
#  'a man and a woman playing in a pool ',
#  'a man in a black shirt is on a surfboard ',
#  'a dog and a cat sitting on a couch ',
#  'a man is painting a mural on a wall ',
#  'a man standing on top of a mountain with a pack of animals ',
#  'a horse drawn carriage with two people riding on it ',
#  'a woman is pulling a cart of groceries ',
#  'two girls walking down a street in front of a store ',
#  'a young girl and a young boy standing in a room ',
#  'a boy sitting on a bench with a stuffed animal ',
#  'a man riding a bike down a street ',
# ...

# %%
git_captions
# Out:
# ['crossing a suspension bridge in nepal',
#  'a couple of kids sitting on top of a rock.',
#  'a man holding a baby in a game room.',
#  'a person on ice climbing up a steep rock face.',
#  'two dogs running in a yard with a red house in the background.',
#  'a woman and a child playing in a pool.',
#  'a baby is chewing on a red pipe.',
#  'a young boy sitting on a colorful inflatable slide.',
#  'a woman and a child playing in a pool.',
#  'a girl in a pool with a green goggles.',
#  'a man in red shorts is on a surfboard.',
#  'a cat and a dog playing with each other.',
#  'a woman is reading a book in a temple.',
#  'a man walking in the mountains with a backpack.',
#  'a horse drawn carriage with people riding in it.',
#  'a man pushing a shopping cart with a child.',
#  'two women walking down a street next to a store.',
#  'a young boy and a young girl in a ballet class.',
#  'a young boy sitting on top of a tiger.',
#  'a man riding a bike down a street.',
# ...

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/nlpconnect/vit-gpt2-image-captioning"
headers = {"Authorization": ai_api_key}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

while True:
    output = query(image)
    try:
        generated_text = output[0]['generated_text']
        print(generated_text)
        caption2 = generated_text
        break  # Si no hay KeyError, sal del bucle
    except KeyError:
        print("KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...")
# Out:
# a desk with a computer and a keyboard

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/microsoft/git-large-coco"
headers = {"Authorization": ai_api_key}

def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

while True:
    output = query(image)
    try:
        generated_text = output[0]['generated_text']
        print(generated_text)
        caption3 = generated_text
        break  # Si no hay KeyError, sal del bucle
    except KeyError:
        print("KeyError: 'generated_text' no se encontró en la respuesta. Intentando de nuevo...")
# Out:
# a desk with a computer, a cup, a bottle, a keyboard, and a laptop.

# %%
# Abre el archivo para lectura
with open('frases.txt', 'r') as archivo:
    # Lee todas las líneas y las guarda en una lista
    lineas = archivo.readlines()

# Si necesitas remover el salto de línea al final de cada línea
lineas = [linea.strip() for linea in lineas]

# Ahora 'lineas' contiene todas las líneas del archivo
print(lineas)
# Out:
# ['Hikers traversing a rope bridge above a rocky river gorge.', 'Two kids sitting on a red rock formation under a twilight sky.', 'Man holding a baby, both looking sideways, indoors, with colorful background.', 'Climber ascending a frozen waterfall with ice axes and crampons.', 'Two dogs playing in a grassy yard near a wooden building.', 'Woman splashing water at a child in a kiddie pool outdoors.', 'Toddler biting on red toy outdoors on a sunny day.', 'Child in red shirt sliding down colorful inflatable slide.', 'Woman and child near car and pool in a sunny backyard setting.', 'Child with green goggles giving peace sign in sunlit swimming pool.', 'Man sandboarding down dune with blue sky in background.', 'Dog and cat playing or fighting on a black office chair.', 'Person reading beside ornate golden doors in a dimly lit room.', 'Hiker trekking towards snow-capped mountains under a stormy sky.', 'Horse-drawn carriage on a street in the rain with passengers and driver.', 'Child pushing
# ...

# %%
import requests

API_URL_SBERT = "https://api-inference.huggingface.co/models/sentence-transformers/all-mpnet-base-v2"
headers = {"Authorization": ai_api_key}

def query(payload):
	response = requests.post(API_URL_SBERT, headers=headers, json=payload)
	return response.json()

output = query({
	"inputs": {
		"source_sentence": "a purple monster teddy bear sitting on a bed with a green tongue and yellow eyes",
		"sentences": [
			caption1,
			caption2,
			caption3
		]
	},
})

print(output)
# Out:
# [0.2406405806541443, 0.26012831926345825, 0.32139521837234497]

# %%
API_URL_SBERT = "https://api-inference.huggingface.co/models/sentence-transformers/all-mpnet-base-v2"
def querySBERT(payload):
	response = requests.post(API_URL_SBERT, headers=headers, json=payload)
	return response.json()

# %%
blip_stats= []
git_stats =[]
vit_stats =[]
for i in range(0,27):
    print('Caption No. ',i)
    human = lineas[i]
    blip = blip_captions[i]
    git = git_captions[i]
    vit = vit_captions[i]
    output = querySBERT({
        "inputs": {
            "source_sentence": human,
            "sentences": [
                blip,
                git,
                vit
                        ]
                },
            })
    print(output)
    blip_stats.append(output[0])
    git_stats.append(output[1])
    vit_stats.append(output[2])
# Out:
# Caption No.  0
# [0.6959174871444702, 0.532158374786377, 0.3982439935207367]
# Caption No.  1
# [0.45056235790252686, 0.8604589104652405, 0.2990497052669525]
# Caption No.  2
# [0.6796371340751648, 0.7812984585762024, 0.6687676310539246]
# Caption No.  3
# [0.5026479959487915, 0.7368745803833008, 0.26699358224868774]
# Caption No.  4
# [0.6936469078063965, 0.7093157172203064, 0.8123795986175537]
# Caption No.  5
# [0.7741315960884094, 0.7769784331321716, 0.7676206231117249]
# Caption No.  6
# [0.5593932867050171, 0.4576028883457184, 0.3247661888599396]
# Caption No.  7
# [0.49213218688964844, 0.6011183261871338, 0.17978963255882263]
# Caption No.  8
# [0.45819592475891113, 0.5684449672698975, 0.2155948430299759]
# Caption No.  9
# [0.3353067934513092, 0.6375129222869873, 0.2030145525932312]
# Caption No.  10
# [0.6362444162368774, 0.3837537169456482, 0.35035014152526855]
# Caption No.  11
# [0.6612295508384705, 0.7261163592338562, 0.6235235929489136]
# Caption No.  12
# ...

# %%
import ast
mean = 0
blip_stats = ast.literal_eval(lineas[-1])
# meanF = mean/len(blip_stats)
for stat in blip_stats:
    mean += stat
meanF = mean/len(blip_stats)
meanF
# Out:
# 0.8150741585043304

# %%
mean = 0
for stat in git_stats:
    mean += stat
meanF = mean/len(blip_stats)
meanF
# Out:
# 0.6423657404051887

# %%
mean = 0
for stat in vit_stats:
    mean += stat
meanF = mean/len(blip_stats)
meanF
# Out:
# 0.439595267728523

# %%
import os
import openai
import sys

# %%
def generate_literature(genre = "romantic", inspiration = "romanticism", caption = "the sunset", length = "100", type_of_literature = "poem"):

    '''
        @PARAMS
        length (int): length of the generated literature, the minimum is 10 and the max is 400
        genre (str): genre of the generated literature, has to be either romantic, gothic or fantastic-realism
        inspiration(str): the movement that will define the literature, has to be either, Romanticism, Realism or Naturalism
        caption (str): the generated caption obtained from the image
        type_of_literature (str): the type of the literary text to be generated, has to be either, fable, story or poem
    '''
    content_system = "You are a "+ genre+  " spanish writter from the, "+ inspiration
    content_user = "make a "+ length+ "Words "+ type_of_literature+ " of this caption "+ caption
    openai.organization = "org-X9t5LSUVjPl0ceRHpyGWv4ts"
    openai.api_key = api_key
    completion = openai.chat.completions.create(
        model="gpt-4",
        messages=[
        {"role": "system", "content": content_system},
        {"role": "user", "content": content_user}
        ]
    )
    return completion.choices[0].message

# %%
data = {
    "genre":["romantic"],
    "inspiration":["romanticism"],
    "length":["100"],
    "literature":["poem"]
}
df = pd.DataFrame(data)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/rene.ventura/Downloads/AIproject/project.ipynb Cell 14 line 7
#       <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X22sZmlsZQ%3D%3D?line=0'>1</a> data = {
#       <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X22sZmlsZQ%3D%3D?line=1'>2</a>     "genre":["romantic"],
#       <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X22sZmlsZQ%3D%3D?line=2'>3</a>     "inspiration":["romanticism"],
#       <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X22sZmlsZQ%3D%3D?line=3'>4</a>     "length":["100"],
#       <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X22sZmlsZQ%3D%3D?line=4'>5</a>     "literature":["poem"]
# ...

# %%
def ultimate_caption(caption, caption2, caption3):
    content_system = "you are a literature teacher"
    content_user = "enhance the first: "+caption + " ,sentence with these other two, "+ caption2+", "+caption3+ " and make a more complex and more coherent sentence of 20 words from that"
    openai.organization = "org-X9t5LSUVjPl0ceRHpyGWv4ts"
    openai.api_key = api_key
    completion = openai.chat.completions.create(
        model="gpt-4",
        messages=[
        {"role": "system", "content": content_system},
        {"role": "user", "content": content_user}
        ]
    )
    return completion.choices[0].message

# %%
data = ultimate_caption(caption=caption1, caption2=caption2, caption3=caption3)
# Accede directamente al valor de "content" desde el objeto de respuesta
definitive_caption = data.content

# Imprime el valor
print(definitive_caption)
# Out:
# A singular stuffed animal, distinguished by a peculiar green tongue sticking out, finds itself perched precariously on the cozy comfort of a bedroom's well-tucked bed.

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/sentence-transformers/all-mpnet-base-v2"
headers = {"Authorization": ai_api_key}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

output = query({
	"inputs": {
		"source_sentence": "a purple monster teddy bear sitting on a bed with a green tongue and yellow eyes",
		"sentences": [
			
			caption1,
			caption2,
			caption3,
			definitive_caption
		]
	},
})

print(output)
import pandas as pd
pd.set_option('display.max_colwidth', None)
data = {
    'Modelo': ['Humano', 'BLIP', 'GIT', 'VIT', 'GPT-4 Transformed sentence'],
    
    'Sentence': ['a purple monster teddy bear sitting on a bed with a green tongue and yellow eyes', 
                 caption1, 
                 caption2,
                 caption3,
				 definitive_caption],
    'SBERT sentence similarity': [1,output[0], output[1],output[2], output[3]]
}

df = pd.DataFrame(data)

df
# Out:
# [0.5856759548187256, 0.6210499405860901, 0.5856759548187256, 0.6338117718696594]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/rene.ventura/Downloads/AIproject/project.ipynb Cell 15 line 2
#      <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X25sZmlsZQ%3D%3D?line=9'>10</a> output = query({
#      <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X25sZmlsZQ%3D%3D?line=10'>11</a> 	"inputs": {
#      <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X25sZmlsZQ%3D%3D?line=11'>12</a> 		"source_sentence": "a purple monster teddy bear sitting on a bed with a green tongue and yellow eyes",
#    (...)
#      <a href='vscode-notebook-cell:/Users/rene.ventura/Downloads/AIproject/project.ipynb#X25sZmlsZQ%3D%3D?line=19'>20</a> 	},
# ...

# %%
data = generate_literature(caption=definitive_caption, length="100", )
# Accede directamente al valor de "content" desde el objeto de respuesta
content_value = data.content

# Imprime el valor
print(content_value)
# Out:
# En la serena quietud de un cuarto encantado,
# un animal singular, encontramos posado,
# distinguido y único, con la lengua de esmeralda mostrado,
# en la cuna confortable, con cuidado acomodado.
#
# De su tasita de té salen sueños dorados,
# al compás de suaves susurros etéreos, al viento desplegados,
# una historia de ensueño en los corazones, ha dejado,
# amor y ternura, en un tapiz de estrellas amarrado.
#
# La noche cae suave sobre su pelaje bordado,
# los recuerdos que guarda, en hilos de luna tejidos, quedan guardados,
# silencioso y estático, junto a sueños y risas anhelados
# el animal de felpa, con su lengua verde, se queda a nuestro lado.
#
# Desde su trono aterciopelado, una realidad paralela ha espiado,
# una muñeca de trapo de mil historias y amores acompañado.
# Con su lengua peculiar, de la vida ha probado,
# en la serena quietud del dormitorio, su reino amado.
